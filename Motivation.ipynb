# %% [markdown]
# # Recognition of Pollen Using CNN

# %% [markdown]
# ![](images_presentation/capture.png)

# %% [markdown]
# ![](images_presentation/P.jpg)
# ![](images_presentation/NP.jpg)

# %% [markdown]
# ![example.png](attachment:example.png)

# %% [markdown]
# # Results:
#
# Testing different configurations for a shallow Neuronal Network

# %% [markdown]
# ![kernels1l.png](attachment:kernels1l.png)

# %% [markdown]
# ![kernelsize1l.png](attachment:kernelsize1l.png)

# %% [markdown]
# ![pool_strides.png](attachment:pool_strides.png)

# %% [markdown]
# ![performance_shallow.png](attachment:performance_shallow.png)

# %% [markdown]
# ![performance_state1.png](attachment:performance_state1.png)

# %% [markdown]
# ![visualization2.jpg](attachment:visualization2.jpg)

# %% [markdown]
# # Open Pose
#
#
# ![](images_presentation/architecture.png)

# %% [markdown]
# ![Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%209.50.16%20a.%20m..png](attachment:Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%209.50.16%20a.%20m..png)

# %% [markdown]
# ![Copia%20de%20Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.00.55%20a.%20m..png](attachment:Copia%20de%20Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.00.55%20a.%20m..png)

# %% [markdown]
# ![Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.01.04%20a.%20m..png](attachment:Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.01.04%20a.%20m..png)

# %% [markdown]
# ![Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.01.30%20a.%20m..png](attachment:Captura%20de%20pantalla%202018-01-19%20a%20la%28s%29%2010.01.30%20a.%20m..png)

# %% [markdown]
# ![resultados.png](attachment:resultados.png)

# %% [markdown]
# # Bonus

# %% [markdown]
# <video controls src="images_presentation/Symposium_final_latest.mp4" />
